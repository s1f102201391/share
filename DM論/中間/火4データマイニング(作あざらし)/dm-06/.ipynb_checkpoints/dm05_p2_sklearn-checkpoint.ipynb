# %% [markdown]
# ### Sample program for Naive Bayes Classifier (small test sample)
# 単純ベイズ分類器のサンプルプログラム(小サンプルでの実行例)

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ![image.png](attachment:104e4cd5-1e79-4871-9089-dfea11a58669.png)

# %% [markdown]
# #### Make DataFrame

# %% [markdown]
# ![image.png](attachment:d25c5bbc-1c10-449d-91df-3bb7e98b04b6.png)

# %%
df = pd.DataFrame(
   [
       ['O', 'USA great Democrats care mother'],
       ['H', 'mother love Democrats care mother USA'],
       ['T', 'Russia fake USA Mexico great Mexico haters'],
   ])
df.columns = ['category', 'text']
print(df.shape)
print(df.info())
display(df.head())
# Out:
# (3, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  3 non-null      object
#  1   text      3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# None
#   category                                        text
# 0        O             USA great Democrats care mother
# 1        H       mother love Democrats care mother USA
# 2        T  Russia fake USA Mexico great Mexico haters

# %% [markdown]
# ![image.png](attachment:0cc610f6-2018-4e71-a741-26c977275f63.png)

# %% [markdown]
# #### Obtain X_train (data) and y_train (true category)

# %%
X_train = df['text']
y_train = df['category']
print(X_train)
print(y_train)
# Out:
# 0               USA great Democrats care mother
# 1         mother love Democrats care mother USA
# 2    Russia fake USA Mexico great Mexico haters
# Name: text, dtype: object
# 0    O
# 1    H
# 2    T
# Name: category, dtype: object

# %% [markdown]
# #### Specify X_test and y_test

# %%
X_test = ['USA Democrats mother']
print(X_test)
# Out:
# ['USA Democrats mother']

# %% [markdown]
# #### Collect words

# %% [markdown]
# ![image.png](attachment:8dd67cf5-8c68-4b83-9e4d-c64cb9990461.png)

# %%
vectorizer = CountVectorizer()
vectorizer.fit(X_train)
vocab = vectorizer. get_feature_names_out()
print('Vocabulary size:', len(vocab))
print(vocab)
# Out:
# Vocabulary size: 10
# ['care' 'democrats' 'fake' 'great' 'haters' 'love' 'mexico' 'mother'
#  'russia' 'usa']

# %% [markdown]
# #### Make BoW (word frequency vectors)

# %% [markdown]
# ![image.png](attachment:6b1adfd8-e29e-4763-8704-ba2821f6cb1f.png)

# %% [markdown]
# ![image.png](attachment:8884d54a-1c00-4efe-805f-b5cc883ee128.png)

# %%
X_train_bow = vectorizer.transform(X_train)
X_test_bow = vectorizer.transform(X_test)
print('X_train_bow:')
print(repr(X_train_bow))
print('X_test_bow:')
print(repr(X_test_bow))
# Out:
# X_train_bow:
# <3x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 16 stored elements in Compressed Sparse Row format>
# X_test_bow:
# <1x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Display BoW

# %%
Xbow = pd.DataFrame(X_train_bow.toarray(), 
                    index=y_train, columns=vocab)
display(Xbow)
# Out:
#           care  democrats  fake  great  haters  love  mexico  mother  russia  \
# category
# O            1          1     0      1       0     0       0       1       0
# H            1          1     0      0       0     1       0       2       0
# T            0          0     1      1       1     0       2       0       1
#
#           usa
# category
# O           1
# H           1
# T           1

# %% [markdown]
# #### Training of naive Bayes classifier

# %% [markdown]
# ![image.png](attachment:d6266adc-4010-453a-a665-9c033ce623f8.png)

# %%
model = MultinomialNB(alpha=1.0, class_prior=[15/50,10/50,25/50])
model.fit(X_train_bow, y_train)
print(model.classes_)
train_score = model.score(X_train_bow, y_train)
print('Train accuracy:', train_score)
# Out:
# ['H' 'O' 'T']
# Train accuracy: 1.0

# %% [markdown]
# #### Prediction using naive Bayes classifier after training

# %% [markdown]
# ![image.png](attachment:b520fe5b-8680-45da-952a-25871265b290.png)

# %%
proba = model.predict_proba(X_test_bow)
results = pd.DataFrame(proba, columns=model.classes_)
print('Prediction:')
display(results)
print(model.predict(X_test_bow))
# Out:
# Prediction:
#          H         O         T
# 0  0.56466  0.304573  0.130767
# ['H']

# %% [markdown]
# /------------------------------------------------------------
# ![image.png](attachment:ee20cd84-0617-4fb7-9a17-66877c5eea06.png)
# ![image.png](attachment:d5d88471-04c3-4b8f-a60d-40bd0d3d8bbf.png)
# ![image.png](attachment:a5caf578-461b-46fe-b701-648de681c3e5.png)
# ![image.png](attachment:c9c1cc10-b368-4063-ae93-7df29ff18910.png)
