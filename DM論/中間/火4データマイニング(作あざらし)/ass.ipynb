# %% [markdown]
# 2
# ![image.png](attachment:75a64bcd-9381-466c-8b04-188fa3f587a2.png)

# %% [markdown]
# 3
# ![image.png](attachment:67047878-90a7-4b99-85d6-726a34c26264.png)

# %% [markdown]
# 4
# ![image.png](attachment:6b988b55-6a0d-4ddb-93a8-49c522460e98.png)

# %% [markdown]
# 6
# ![image.png](attachment:79ab9eb0-679a-487c-a5e6-9c91a7469b20.png)
