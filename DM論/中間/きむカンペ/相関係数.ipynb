# %% [markdown]
# ![スクリーンショット (447).png](attachment:31e53bc7-3b22-49b6-b451-7a3fcc9e48ad.png)

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv('height.csv',sep='\s+')
# display(df.head())
# df.corr()

# %% [markdown]
# ![スクリーンショット (449).png](attachment:c6df41ab-887e-4228-a863-540f9af6fa95.png)
