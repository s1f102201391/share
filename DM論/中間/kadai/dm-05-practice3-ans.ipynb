# %% [markdown]
# ![スクリーンショット (513).png](attachment:aaf0bb47-5558-400e-a7f6-701b715c28d8.png)![スクリーンショット (514).png](attachment:10f3b61c-83c0-44fb-ae72-dc06ba5e8862.png)![スクリーンショット (515).png](attachment:ae02a617-ef09-4a4b-a91b-4154fcfa97ca.png)

# %%
import numpy as np
import pandas as pd

# %%
pre = pd.Series([10/(10+15+25), 15/(10+15+25), 25/(10+15+25)])
pre.index=['O', 'H', 'T']
print(pre)
# Out:
# O    0.2
# H    0.3
# T    0.5
# dtype: float64

# %% [markdown]
# **Ans. 1:  O: 0.2,  H: 0.3,  T: 0.5**

# %%
df = pd.DataFrame(
       [[1, 1, 1],
        [1, 1, 2],
        [1, 0, 0]]
)
df.index=['O', 'H', 'T']
df.columns=['USA', 'Democrats', 'mother']
display(df)
# Out:
#    USA  Democrats  mother
# O    1          1       1
# H    1          1       2
# T    1          0       0

# %%
df += np.ones((3,3), dtype='int')
display(df)
# Out:
#    USA  Democrats  mother
# O    2          2       2
# H    2          2       3
# T    2          1       1

# %%
df['tot'] = [5, 6, 7]
df['tot'] += 10
display(df)
# Out:
#    USA  Democrats  mother  tot
# O    2          2       2   15
# H    2          2       3   16
# T    2          1       1   17

# %%
like = pd.Series({  # USA, Democrats, mother, mother
    'O':(2/15) * (2/15) * (2/15) * (2/15),
    'H':(2/16) * (2/16) * (3/16) * (3/16),
    'T':(2/17) * (1/17) * (1/17) * (1/17),
})
print(like)
# Out:
# O    0.000316
# H    0.000549
# T    0.000024
# dtype: float64

# %% [markdown]
# **Ans. 2:  O: 0.000316,  H: 0.000549,  T: 0.000024**

# %%
post = like * pre
print(post)
# Out:
# O    0.000063
# H    0.000165
# T    0.000012
# dtype: float64

# %% [markdown]
# **Ans. 3: O: 0.000063,  H: 0.000165,  T: 0.000012**

# %%
print(post/post.sum())
# Out:
# O    0.263399
# H    0.686709
# T    0.049892
# dtype: float64

# %% [markdown]
# **Ans. 4: O: 0.263, H: 0.687, T: 0.050**

# %% [markdown]
# **Ans. 5: Ms. H**
