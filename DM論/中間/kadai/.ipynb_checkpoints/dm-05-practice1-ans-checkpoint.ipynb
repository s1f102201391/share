# %% [markdown]
# ![スクリーンショット (507).png](attachment:c62a8f96-dfe4-4f6d-bcfc-9c57db865911.png)![スクリーンショット (506).png](attachment:68f214ae-b162-48c7-b4e3-17067dd7bcd2.png)![スクリーンショット (505).png](attachment:1f77baa1-684a-41fa-b630-e0fdfb5e0d8f.png)

# %% [markdown]
# #### (1)

# %%
pre=1/1000; like_tp=0.95; like_tn=0.90

# %%
posi=like_tp*pre + (1-like_tn)*(1-pre); print(posi)
# Out:
# 0.10084999999999998

# %%
post=like_tp*pre/posi; print(post)
# Out:
# 0.009419930589985128

# %% [markdown]
# **Ans. 0.94%**

# %% [markdown]
# #### (2)

# %%
pre2=post; like_tp2=0.98; like_tn2=0.95

# %%
posi2=like_tp2*pre2 + (1-like_tn2)*(1-pre2); print(posi2)
# Out:
# 0.058760535448686216

# %%
post2=like_tp2*pre2/posi2; print(post2)
# Out:
# 0.15710428619642244

# %% [markdown]
# **Ans. 15.71%**
