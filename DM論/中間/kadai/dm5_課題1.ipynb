# %% [markdown]
# ![スクリーンショット (502).png](attachment:94f792e3-d6bd-459f-82f7-b3984d6ea464.png)![スクリーンショット (503).png](attachment:e6ba3db4-2485-4cfa-92c1-96d3dd32af3f.png)

# %% [markdown]
# ### Assignment 1

# %% [markdown]
# #### 1.

# %%
pre=1/200; like_tp=0.70; like_tn=0.99

# %%
posi=like_tp*pre + (1-like_tn)*(1-pre); print(posi)
# Out:
# 0.013450000000000009

# %%
post_tp=like_tp*pre/posi; print(post_tp)
# Out:
# 0.26022304832713733

# %% [markdown]
# **Ans. 26.0%**

# %% [markdown]
# #### 2.

# %%
nega=(1-like_tp)*pre + like_tn*(1-pre); print(nega)
# Out:
# 0.9865499999999999

# %%
post_tn=like_tn*(1-pre)/nega; print(post_tn)
# Out:
# 0.9984795499467843

# %% [markdown]
# **Ans. 99.8%**

# %% [markdown]
# #### 3.

# %%
pre=1/10; like_tp=0.70; like_tn=0.99

# %%
posi=like_tp*pre + (1-like_tn)*(1-pre); print(posi)
# Out:
# 0.079

# %%
post_tp=like_tp*pre/posi; print(post_tp)
# Out:
# 0.8860759493670886

# %% [markdown]
# **Ans. 88.6%**

# %%
nega=(1-like_tp)*pre + like_tn*(1-pre); print(nega)
# Out:
# 0.921

# %%
post_tn=like_tn*(1-pre)/nega; print(post_tn)
# Out:
# 0.9674267100977199

# %% [markdown]
# **Ans. 96.7%**

# %% [markdown]
# #### 4.

# %%
pre2=1-post_tn

# %%
nega2=(1-like_tp)*pre2 + like_tn*(1-pre2); print(nega2)
# Out:
# 0.9675244299674267

# %%
post_tn2=like_tn*(1-pre2)/nega2; print(post_tn2)
# Out:
# 0.9899000100999898

# %% [markdown]
# **Ans. 99.0%**
