# %% [markdown]
# ![スクリーンショット (508).png](attachment:20a0bb6c-93c1-48c2-8f1c-780d5be1f060.png)![スクリーンショット (509).png](attachment:ab813dc7-6197-4e92-9d53-14b9ea105f6d.png)![スクリーンショット (510).png](attachment:eedb4d40-5fb0-46c8-955e-5b00960e6384.png)![スクリーンショット (511).png](attachment:0d941a26-8435-43ba-a478-77ddc8ea8848.png)![スクリーンショット (512).png](attachment:cb1edc44-a4e0-4a96-aa69-0225a0deee2d.png)

# %%
import numpy as np
import pandas as pd

# %%
pre = pd.Series([10/(10+15+25), 15/(10+15+25), 25/(10+15+25)])
pre.index=['O', 'H', 'T']
print(pre)
# Out:
# O    0.2
# H    0.3
# T    0.5
# dtype: float64

# %% [markdown]
# **Ans. 1:  O: 0.2,  H: 0.3,  T: 0.5**

# %%
df = pd.DataFrame(
       [[1, 1, 1],
        [1, 1, 2],
        [1, 0, 0]]
)
df.index=['O', 'H', 'T']
df.columns=['USA', 'Democrats', 'mother']
display(df)
# Out:
#    USA  Democrats  mother
# O    1          1       1
# H    1          1       2
# T    1          0       0

# %%
df += np.ones((3,3), dtype='int')
display(df)
# Out:
#    USA  Democrats  mother
# O    2          2       2
# H    2          2       3
# T    2          1       1

# %%
df['tot'] = [5, 6, 7]
df['tot'] += 10
display(df)
# Out:
#    USA  Democrats  mother  tot
# O    2          2       2   15
# H    2          2       3   16
# T    2          1       1   17

# %%
like = pd.Series({
    'O':(2/15) * (2/15) * (2/15),
    'H':(2/16) * (2/16) * (3/16),
    'T':(2/17) * (1/17) * (1/17),
})
print(like)
# Out:
# O    0.002370
# H    0.002930
# T    0.000407
# dtype: float64

# %% [markdown]
# **Ans. 2:  O: 0.00237,  H: 0.00293,  T: 0.000407**

# %%
post = like * pre
print(post)
# Out:
# O    0.000474
# H    0.000879
# T    0.000204
# dtype: float64

# %% [markdown]
# **Ans. 3: O: 0.000474,  H: 0.000879,  T: 0.0000204**

# %%
print(post/post.sum())
# Out:
# O    0.304573
# H    0.564660
# T    0.130767
# dtype: float64

# %% [markdown]
# **Ans. 4: O: 0.305, H: 0.565, T: 0.131**

# %% [markdown]
# **Ans. 5: Ms. H**
