# %% [markdown]
# # ニューラルネットワークのプログラム

# %% [markdown]
# ##### 単純パーセプトロン

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import  os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # for mac OS

# %%
df= pd.read_csv('points_and.csv', sep=',', skiprows=0, header=0)
data_train = df[['x1', 'x2']]
class_train = df['class']
print('data:', data_train.shape)
print('class:', class_train.shape)
# Out:
# data: (4, 2)
# class: (4,)

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:dee54bda-badd-41ec-b7fd-5e5c12d7aed2.png)![image.png](attachment:006f1ec7-d801-4f03-83d8-53ff1e792fa4.png)![image.png](attachment:11e67218-287e-44c7-bb26-d685eae5fd2b.png)![image.png](attachment:9d091bb7-f42f-47b1-ab8e-60f61a451d3a.png)![image.png](attachment:dd3c4827-1445-47bc-bcab-d7399b5b0cd8.png)

# %%
# %%time
model.compile(optimizer='sgd', loss='binary_crossentropy',
              metrics=['accuracy'])
fit_log = model.fit(data_train, class_train, epochs=1000, batch_size=1)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8581 - accuracy: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8562 - accuracy: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s 999us/step - loss: 0.8543 - accuracy: 0.7500
# Epoch 4/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8525 - accuracy: 0.7500
# Epoch 5/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8507 - accuracy: 0.7500
# Epoch 6/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8488 - accuracy: 0.7500
# Epoch 7/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8470 - accuracy: 0.7500
# Epoch 8/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8452 - accuracy: 0.7500
# Epoch 9/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8434 - accuracy: 0.7500
# Epoch 10/1000
# ...

# %% [markdown]
# ![image.png](attachment:3a53194c-7cb5-4de1-9865-8675629ecd49.png)

# %%
plt.plot(fit_log.history['accuracy'], label='train')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:8789edc9-e26b-467c-aa6c-503d41607a90.png)

# %%
pred = model.predict(data_train)
print(pred)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[0.06553052]
#  [0.24401717]
#  [0.2588607 ]
#  [0.6165155 ]]

# %% [markdown]
# ![image.png](attachment:555d58a2-caeb-4803-9463-f2c5599ab764.png)
