# %% [markdown]
# ![スクリーンショット (382).png](attachment:d567590e-69bd-4e6b-927b-15f5f729813c.png)
# ![スクリーンショット (383).png](attachment:5a24959e-e402-4c3e-b5c6-688bbf25c322.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img_in = 'img_color_2.jpg'
img = Image.open(img_in)

# %%
print(img.format, img.size,
      img.width, img.height, img.mode)
# Out:
# JPEG (15, 5) 15 5 RGB

# %%
plt.imshow(img)
plt.show()

# %%
data=np.array(img)
print(data.shape)
# Out:
# (5, 15, 3)

# %%
print(data[:, :, 0])
# Out:
# [[  0 255 255   0  27  31   0  12  20  25 198 237 112 174 223]
#  [  0 255 255   0  27  31   0  12  20  25 198 237 112 174 223]
#  [  0 255 255   0  27  31   0  12  20  25 198 237 112 174 223]
#  [  0 255 255   0  27  31   0  12  20  25 198 237 112 174 223]
#  [  0 255 255   0  27  31   0  12  20  25 198 237 112 174 223]]

# %%
print(data[:, :, 1])
# Out:
# [[ 22 226 232  53 242 224  20  11   1   0  35  23   0  34  16]
#  [ 22 226 232  53 242 224  20  11   1   0  35  23   0  34  16]
#  [ 22 226 232  53 242 224  20  11   1   0  35  23   0  34  16]
#  [ 22 226 232  53 242 224  20  11   1   0  35  23   0  34  16]
#  [ 22 226 232  53 242 224  20  11   1   0  35  23   0  34  16]]

# %%
print(data[:, :, 2])
# Out:
# [[  0 118  91   0   0  81  48 164 189 147 224 183  19  35   0]
#  [  0 118  91   0   0  81  48 164 189 147 224 183  19  35   0]
#  [  0 118  91   0   0  81  48 164 189 147 224 183  19  35   0]
#  [  0 118  91   0   0  81  48 164 189 147 224 183  19  35   0]
#  [  0 118  91   0   0  81  48 164 189 147 224 183  19  35   0]]

# %%
nd_c = np.zeros((500, 1500, 3)).astype('uint8')
nd_c[0:500, 100:400, 0] = 255
nd_c[0:500, 600:900, 1] = 255
nd_c[0:500, 1100:1400, 2] = 255

# %%
img_c = Image.fromarray(nd_c)
plt.imshow(img_c)
plt.show()

# %%
name = 'img_color.jpg'
img_c.save(name, quality=95)
