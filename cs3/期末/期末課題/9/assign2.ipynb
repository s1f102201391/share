# %% [markdown]
# ![スクリーンショット (384).png](attachment:1502b411-cdf2-4e1e-b262-8f111c08381c.png)
# ![スクリーンショット (385).png](attachment:206b4db3-2462-4f37-b142-5d0c4b0e753e.png)
# ![スクリーンショット (386).png](attachment:e9d3f1c2-062d-4eab-9082-07770c46c819.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

# %%
img_in = 'cat_sample.jpg'
img = Image.open(img_in)

# %%
print(img.format, img.size,
      img.width, img.height, img.mode)
# Out:
# PNG (750, 1334) 750 1334 RGBA

# %%
plt.imshow(img)
plt.show()

# %%
data=np.array(img)
print(data.shape)
# Out:
# (1334, 750, 4)

# %%
print(data[800, 200, :])
# Out:
# [ 56  52  51 255]

# %%
img_small = img.resize((30,50))
plt.imshow(img_small)
plt.show()

# %%
img_rot = img.rotate(60)
plt.imshow(img_rot)
plt.show()

# %%
img_blur = img.filter(ImageFilter.GaussianBlur(radius=10))
plt.imshow(img_blur)
plt.show()

# %%
img_crop = img.crop((300, 400, 600, 700))
plt.imshow(img_crop)
plt.show()

# %%
img_gray = img.convert('L')  # gray scale
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
img_out = 'cat_gray.jpg'
img_gray.save(img_out, quality=95)
