# %% [markdown]
# ![スクリーンショット 2024-01-21 174851.png](attachment:ef071eb0-2b72-4c6a-85a9-04b998642e13.png)

# %% [markdown]
# ##### p  :  素数
# ##### q  :  素数（ただし、p ≠ q）
# ##### n  :  p * q
# ##### e  :  p-1 と q-1 に対して互いに素な数（ただし e > 2）
# ##### z  :  p-1 と q-1 の最小公倍数
# ##### d  :  de - yz = 1 の整数解 (d, y) のどれか一つ
#
# ##### 上記の数字のうち、n, e が公開鍵、d が秘密鍵
# ##### 平文と暗号文の関係は、
# ##### ① 平文 ^ e (mod n) = 暗号文
# ##### ② 暗号文 ^ d (mod n) = 平文
#
#
#
# ### C=7^3mod55は7^3を55で割ったあまり→13

# %% [markdown]
# # 該当スライド

# %% [markdown]
# ![スクリーンショット 2024-01-21 174905.png](attachment:eb6bbde2-3eec-4e50-9bf7-b277daade894.png)
