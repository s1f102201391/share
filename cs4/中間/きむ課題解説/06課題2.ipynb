# %% [markdown]
# ![スクリーンショット 2023-11-19 175206.png](attachment:162e2a03-89e4-48e3-b97c-746e11356f1a.png)![スクリーンショット 2023-11-19 175223.png](attachment:3c905e17-5fca-4d7d-81df-f37b327d5c23.png)

# %% [markdown]
# # コード

# %%
import ipaddress
subnet = ipaddress.ip_network('192.168.33.192/26', strict=False)

print(subnet.network_address)
print(subnet.broadcast_address)
print(subnet.netmask)
# Out:
# 192.168.33.192
# 192.168.33.255
# 255.255.255.192

# %% [markdown]
# # 該当スライド

# %% [markdown]
# ![スクリーンショット 2023-11-19 175742.png](attachment:ed7736cc-6b10-43da-b5d3-fcc2bc736987.png)![スクリーンショット 2023-11-19 175532.png](attachment:c2cf9a58-bcfd-4e2b-945c-28b2af0d1dee.png)![スクリーンショット 2023-11-19 175601.png](attachment:619ec34c-b6a3-457b-8fe9-9b1e73d10b09.png)![スクリーンショット 2023-11-19 175616.png](attachment:8e1189df-74d3-442a-9fae-34aff574636b.png)![スクリーンショット 2023-11-19 175637.png](attachment:3d49c57c-2987-46c8-ab4d-0d1eb50b817f.png)![スクリーンショット 2023-11-19 175650.png](attachment:6af98c63-761b-43e1-b18b-39ff8c7b56a3.png)![スクリーンショット 2023-11-19 175706.png](attachment:645549b4-f887-4fa5-bbf6-194b6a58514c.png)
