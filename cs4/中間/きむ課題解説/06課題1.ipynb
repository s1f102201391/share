# %% [markdown]
# ![スクリーンショット 2023-11-19 173111.png](attachment:ae592ea0-9979-4d69-aa7b-afcfd953fb16.png)![スクリーンショット 2023-11-19 173129.png](attachment:93bc4537-ed59-4e2a-88bf-31218e81cf3d.png)

# %% [markdown]
# # コード

# %% [markdown]
# #### 10進数→2進数

# %%
num = 255 #ここを変更
format(num, 'b')
# Out:
# '11111111'

# %% [markdown]
# #### 2進数→10進数

# %%
num = '11111111' #ここを変更
int(num,2)
# Out:
# 255

# %% [markdown]
# # 該当スライド

# %% [markdown]
# ![スクリーンショット 2023-11-19 174909.png](attachment:12433284-558c-406c-8ee0-1798ac6b0f1b.png)![スクリーンショット 2023-11-19 174924.png](attachment:27f3590e-b3cb-46c6-be7e-9410e5cfabd6.png)![スクリーンショット 2023-11-19 175055.png](attachment:41d18d7f-ef0e-41cf-a36d-c6df551d00fc.png)
